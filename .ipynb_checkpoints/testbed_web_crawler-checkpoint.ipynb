# %%
import pandas as pd
import numpy as np
import requests
from urllib.parse import urljoin
from bs4 import BeautifulSoup

import web_crawler.scraper_amazon as scraper_amazon

# Our generated code
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
    
# %load_ext autoreload
# %autoreload 2

# %%
step_size = 10

#with open('/libs/data.json') as f:
#    json_data = json.load(f)

products = pd.read_pickle("./data/products_pd.pickle")

products['price_dollar'] = np.nan

i=0

# %%
products.iloc[i:i+step_size]
# Out:
#                 created_t                         product_name quantity  \
# code
# 0819377000120  1537556615  châtaignes pelées et rôties cesares    150 g
# 2000000072530  1533075976               Nestle Aguitas Manzana    300ml
# 2000000074609  1536152379                 Terrine de Chevreuil   180 gr
# 2000000074660  1536214006               TERRINE AUX CHÂTAIGNES   180 gr
# 2126744000002  1461504012                      Bünder Bergkäse      NaN
# 2129746000001  1462721730                            Minitaler      NaN
# 2141870000009  1461503777                        Tilsiter doux      NaN
# 2181121000006  1462721325                  Plateau de fromages      NaN
# 22016065       1425215080                 Jogourt Nature ferme    180 g
# 22016072       1462666897                       Yogourt Ananas    180 g
#
#                                         packaging                      brands  \
# code
# 0819377000120                            conserve                     cesares
# ...

# %%
def _update_headers(search_url):
    """ Update the 'Host' field in the header with the proper Amazon domain
    >>> c = Client()
    >>> print(c.headers['Host'])
    www.amazon.com
    >>> c._update_headers("https://www.amazon.fr/s/lkdjsdlkjlk")
    >>> print(c.headers['Host'])
    www.amazon.fr
    """
    self.base_url = "https://" + \
        search_url.split("://")[1].split("/")[0] + "/"
    self.headers['Host'] = self.base_url.split("://")[1].split("/")[0]

# %%
_CSS_SELECTORS_DESKTOP = {
    "product": "#s-results-list-atf",
    "title": "a.s-access-detail-page > h2",
    "price_currency": "a-link-normal > a-color-base > sx-price-large > sx-price-currency",
    "price_whole" : "sx-price-whole",
    "price_fraction" : "sx-price-fraction",
    "rating": "i.a-icon-star > span",
    "review_nb": "div.a-column.a-span5.a-span-last > \
                div.a-row.a-spacing-mini > \
                a.a-size-small.a-link-normal.a-text-normal",
    "url": "div.a-row.a-spacing-small > div.a-row.a-spacing-none > a['href']",
    "next_page_url": "a#pagnNextLink",
}

# %%
headers = {
            'Host': 'www.amazon.com',
            'User-Agent': _CSS_SELECTORS_DESKTOP,
            'Accept': 'text/html,application/xhtml+xml,\
                application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            }

# %%
search_url = 'https://www.walmart.com/search/?query=%20nestle%20Aguitas%20Manzana'

r = requests.get(search_url)

soup = BeautifulSoup(r.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo">
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <style>
# ...

# %%
trials = 0


search_url = 'https://www.walmart.com/search/?query=%20nestle%20Aguitas%20Manzana'
https://www.walmart.com/search/?query=%20nestle%20Aguitas%20Manzana
soup = BeautifulSoup(res.text, _DEFAULT_BEAUTIFULSOUP_PARSER)


# For each product of the result page
for product in products:
    if len(self.product_dict_list) >= max_product_nb:
        # Check if the maximum number to search has been reached
        break
    else:
        title = _css_select(product,
                            css_selector_dict.get("title", ""))
        price = _css_select(product,
                            css_selector_dict.get("price", ""))
        quant = _css_select(product,
                            css_selector_dict.get("quantity", ""))
        if price != "":
            # format price label
            True

        # store in dict
        product_dict = {'title' : title,
                        'price' : price,
                        'quantity' : quantity
                        }

        css_selector = css_selector_dict.get("url", "")
        url_product_soup = product.select(css_selector)
        if url_product_soup:
            url = urljoin(
                self.base_url,
                url_product_soup[0].get('href'))
            proper_url = url.split("/ref=")[0]
            product_dict['url'] = proper_url
            if "slredirect" not in proper_url:  # slredirect = bad url
                self.product_dict_list.append(product_dict)

# %%
url = "https://www.amazon.com/s/ref=nb_sb_noss?url=search-alias%3Daps&field-keywords=" + query

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.90 Safari/537.36'}
page = requests.get(url, headers=headers)

display(page.content)
